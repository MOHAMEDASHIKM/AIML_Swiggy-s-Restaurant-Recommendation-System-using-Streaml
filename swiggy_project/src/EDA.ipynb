# %% [markdown]
# # IMPORTS

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import re
from pathlib import Path

# ===============================
# Paths
# ===============================

BASE_DIR = Path(__file__).resolve().parent

RAW_PATH = BASE_DIR.parent / "data" / "raw" / "swiggy.csv"
CLEAN_PATH = BASE_DIR.parent / "data" / "processed" / "cleaned_data.csv"

print("Notebook Ready!")
print("Raw File Path:", RAW_PATH)
print("Clean File Path:", CLEAN_PATH)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 4
#       1 import warnings
#       2 warnings.filterwarnings("ignore")
# ----> 4 import pandas as pd
#       5 import numpy as np
#       6 import re
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # DATA SOURCING AND DATA CLEANING

# %%
import os
from pathlib import Path

# Find project root automatically
def find_project_root(target_folder="data"):
    current = Path(os.getcwd())
    while current != current.parent:
        if (current / target_folder).exists():
            return current
        current = current.parent
    raise FileNotFoundError("Project root not found!")

ROOT = find_project_root("data")
RAW_PATH = ROOT / "data" / "raw" / "swiggy.csv"

print("Detected Project Root:", ROOT)
print("Loading:", RAW_PATH)

import pandas as pd
df = pd.read_csv(RAW_PATH)
df.head()
# Out:
# Detected Project Root: d:\DEMO\Swiggy-Restaurant-Recommendation-System-main\swiggy_project
# Loading: d:\DEMO\Swiggy-Restaurant-Recommendation-System-main\swiggy_project\data\raw\swiggy.csv
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 19
#      16 print("Detected Project Root:", ROOT)
#      17 print("Loading:", RAW_PATH)
# ---> 19 import pandas as pd
#      20 df = pd.read_csv(RAW_PATH)
#      21 df.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print(os.getcwd())
# Out:
# d:\DEMO\Swiggy-Restaurant-Recommendation-System-main\swiggy_project\src

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from pathlib import Path

# Since notebook is in project root:
RAW_PATH = Path("data/raw/swiggy.csv")

print("Loading:", RAW_PATH.resolve())

df = pd.read_csv(RAW_PATH)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       1 import warnings
#       2 warnings.filterwarnings("ignore")
# ----> 4 import pandas as pd
#       5 from pathlib import Path
#       7 # Since notebook is in project root:
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  object
#  2   city          148541 non-null  object
#  3   rating        148455 non-null  object
#  4   rating_count  148455 non-null  object
#  5   cost          148410 non-null  object
#  6   cuisine       148442 non-null  object
#  7   lic_no        148312 non-null  object
#  8   link          148541 non-null  object
#  9   address       148455 non-null  object
#  10  menu          148541 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 12.5+ MB
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
import numpy as np

df["rating"] = df["rating"].replace("--", np.nan)
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

df["rating"].fillna(df["rating"].median(), inplace=True)

df["rating_count"] = pd.to_numeric(df["rating_count"], errors="coerce").fillna(0)

# %%
df["cost"] = df["cost"].replace("--", np.nan)
df["cost"] = pd.to_numeric(df["cost"], errors="coerce")

# If more than 80% missing → fill by group median or global median
cost_median = df["cost"].median()
df["cost"].fillna(cost_median, inplace=True)

df["cost"].isna().sum()
# Out:
# np.int64(148541)

# %%
df["name"] = df["name"].astype(str)
df["city"] = df["city"].astype(str)
df["cuisine"] = df["cuisine"].astype(str)
df["address"] = df["address"].astype(str)

# %%
df["cuisine"] = df["cuisine"].str.lower().str.replace("&", ",")
df["cuisine_list"] = df["cuisine"].str.split(",")
df[["cuisine", "cuisine_list"]].head()
# Out:
#                       cuisine                   cuisine_list
# 0            beverages,pizzas            [beverages, pizzas]
# 1               sweets,bakery               [sweets, bakery]
# 2                   beverages                    [beverages]
# 3            fast food,indian            [fast food, indian]
# 4  italian-american,fast food  [italian-american, fast food]

# %%
df.drop_duplicates(subset=["name", "address"], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.isna().sum()
# Out:
# id                   0
# name                 0
# city                 0
# rating               0
# rating_count         0
# cost            148402
# cuisine              0
# lic_no             144
# link                 0
# address              0
# menu                 0
# cuisine_list         0
# dtype: int64

# %%
df["cost"] = pd.to_numeric(df["cost"], errors="coerce")
df["cost"].fillna(df["cost"].median(), inplace=True)

# %%
df.to_csv("data/processed/cleaned_data.csv", index=False)
print("Cleaned data saved.")
# Out:
# Cleaned data saved.
